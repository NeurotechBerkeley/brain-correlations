# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pierre = pd.read_csv('data/time_test_pierre.csv')
time_p = np.array(pierre.timestamps)
eeg_p = np.array(pierre.ix[:, 1:5])

# %%
ashton = pd.read_csv('data/time_test_ashton.csv')
time_a = np.array(ashton.timestamps)
eeg_a = np.array(ashton.ix[:, 1:5])

# %%
plt.figure(figsize=(14,4))
plt.plot(time_p, eeg_p[:, 2])
plt.plot(time_a, eeg_a[:, 2])
